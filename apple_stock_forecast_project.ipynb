# %% [markdown]
# # 📈 Apple Stock Price Forecast (2019–2024)
# This is a beginner-friendly data science project analyzing Apple stock prices from 2019 to 2024 using Python.
#
# **Goals:**
# - Analyze real-world financial data
# - Visualize trends
# - Apply basic Linear Regression for forecasting
#
# ---

# %%
# !pip install yfinance matplotlib scikit-learn --quiet

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# Download Apple stock data
df = yf.download("AAPL", start="2019-01-01", end="2024-12-31")
df = df.reset_index()

# Use only Date and Close columns
df = df[["Date", "Close"]]
df = df.dropna()

# %%
# Prepare data for modeling
df['Date_ordinal'] = pd.to_datetime(df['Date']).map(pd.Timestamp.toordinal)
X = df['Date_ordinal'].values.reshape(-1, 1)
y = df['Close'].values

model = LinearRegression()
model.fit(X, y)
df['Predicted'] = model.predict(X)

# %%
# Plot actual vs predicted
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Close'], label="Actual", linewidth=2)
plt.plot(df['Date'], df['Predicted'], label="Predicted", linestyle="--")
plt.title("Apple Stock Price & Linear Forecast (2019–2024)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🖼️ Final Forecast Chart
# This is the chart generated in this project:

# %% [markdown]
# <img src="data:image/png;base64,..." width="1000px">

# %% [markdown]
# ---
#
# ### ✅ Tools Used
# - Python
# - yfinance
# - matplotlib
# - scikit-learn
#
# ---
#
# *Made as a first step into quantitative analysis and data science.*
